# %% [markdown]
# # Code for forecasting page

# %% [markdown]
# ## Model information gathering

# %%
# Import dependency
import pandas as pd

# %%
# Read in model summary
model_info = pd.read_csv("../Model_summary.csv")
model_info.head()
# Out:
#         State             Model  R2 Score
# 0    National  LinearRegression  0.603216
# 1     Alabama  LinearRegression  0.956442
# 2     Arizona  LinearRegression  0.882848
# 3    Arkansas  LinearRegression  0.961130
# 4  California  LinearRegression  0.651970

# %%
# Narrow df to state selected
model_used = model_info.loc[model_info['State'] == "Alabama"]
model_used.head()
# Out:
#      State             Model  R2 Score
# 1  Alabama  LinearRegression  0.956442

# %%
# Get state
model_used["State"].item()
# Out:
# 'Alabama'

# %%
# Get model type
model_used["Model"].item()
# Out:
# 'LinearRegression'

# %%
# Get r2 score rounded to two decimals
round(model_used["R2 Score"].item(), 2)
# Out:
# 0.96

# %% [markdown]
# ## Generating csv for feature ranges by state

# %%
# Read in econ features data
econ_features = pd.read_csv('../../Data_Preprocessing/Raw_Data/dataset_na_dropped.csv')

# %%
# Drop unwanted columns
features_df = econ_features

# %%
# Calculate additional features
features_df['education_per_capita'] = features_df['education_million'] / features_df['population_million']
features_df['welfare_per_capita'] = features_df['welfare_million'] / features_df['population_million']

# Drop the non-beneficial columns
columns_to_drop = ['education_million','welfare_million']
features_df = features_df.drop(columns=columns_to_drop, axis=1)

# %%
# Generate data for min and max values for each state and feature
data = []
for state in features_df['state'].unique():
    temp_df = features_df.loc[econ_features['state'] == state]
    for feature in features_df.drop(columns = ['year', 'state', 'population_million']).columns:
        minimum = temp_df[feature].min()
        maximum = temp_df[feature].max()
        record = {'state': state, 'feature':feature, 'min': minimum, 'max': maximum}
        data.append(record)
data
# Out:
# [{'state': 'National', 'feature': 'crime_rate', 'min': 372.0, 'max': 758.1},
#  {'state': 'National',
#   'feature': 'unemployment_rate',
#   'min': 3.71836707699005,
#   'max': 9.86085724560746},
#  {'state': 'National',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 5.3},
#  {'state': 'National',
#   'feature': 'homeownership_rate',
#   'min': 3.72,
#   'max': 9.86},
#  {'state': 'National',
#   'feature': 'minimum_wage_effective',
#   'min': 2.226666666666668,
#   'max': 9.068823529411764},
#  {'state': 'National',
#   'feature': 'CPI_Average',
#   'min': 56.900000000000055,
#   'max': 255.65699999999975},
#  {'state': 'National', 'feature': 'inflation_rate', 'min': -0.4, 'max': 13.5},
#  {'state': 'National',
#   'feature': 'avg_wage_index',
#   'min': 9226.48,
#   'max': 54099.99},
#  {'state': 'National', 'feature': 'poverty_rate', 'min': 12.3, 'max': 16.79},
#  {'state': 'National',
#   'feature': 'education_per_capita',
#   'min': 494.5493097328816,
#   'max': 3602.8157646270524},
#  {'state': 'National',
#   'feature': 'welfare_per_capita',
#   'min': 332.59674110949777,
#   'max': 2168.2455783038663},
#  {'state': 'Alabama', 'feature': 'crime_rate', 'min': 383.7, 'max': 871.7},
#  {'state': 'Alabama', 'feature': 'unemployment_rate', 'min': 3.0, 'max': 11.3},
#  {'state': 'Alabama',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Alabama',
#   'feature': 'homeownership_rate',
#   'min': 66.5,
#   'max': 78.0},
#  {'state': 'Alabama',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Alabama', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Alabama', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Alabama',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Alabama', 'feature': 'poverty_rate', 'min': 13.5, 'max': 26.3},
#  {'state': 'Alabama',
#   'feature': 'education_per_capita',
#   'min': 664.0688259109312,
#   'max': 3061.7766911165445},
#  {'state': 'Alabama',
#   'feature': 'welfare_per_capita',
#   'min': 219.3825910931174,
#   'max': 726.0120406892256},
#  {'state': 'Alaska', 'feature': 'crime_rate', 'min': 455.4, 'max': 891.7},
#  {'state': 'Alaska', 'feature': 'unemployment_rate', 'min': 5.4, 'max': 11.1},
#  {'state': 'Alaska',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Alaska',
#   'feature': 'homeownership_rate',
#   'min': 55.4,
#   'max': 70.0},
#  {'state': 'Alaska',
#   'feature': 'minimum_wage_effective',
#   'min': 3.85,
#   'max': 10.19},
#  {'state': 'Alaska', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Alaska', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Alaska',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Alaska', 'feature': 'poverty_rate', 'min': 9.9, 'max': 19.6},
#  {'state': 'Alaska',
#   'feature': 'education_per_capita',
#   'min': 2242.3597678916826,
#   'max': 5032.926829268293},
#  {'state': 'Alaska',
#   'feature': 'welfare_per_capita',
#   'min': 835.090909090909,
#   'max': 1636.842105263158},
#  {'state': 'Arizona', 'feature': 'crime_rate', 'min': 392.7, 'max': 715.0},
#  {'state': 'Arizona', 'feature': 'unemployment_rate', 'min': 3.8, 'max': 10.3},
#  {'state': 'Arizona',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Arizona',
#   'feature': 'homeownership_rate',
#   'min': 61.7,
#   'max': 71.6},
#  {'state': 'Arizona',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 12.0},
#  {'state': 'Arizona', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Arizona', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Arizona',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Arizona', 'feature': 'poverty_rate', 'min': 13.5, 'max': 33.59},
#  {'state': 'Arizona',
#   'feature': 'education_per_capita',
#   'min': 810.7084557623244,
#   'max': 2264.4883410069806},
#  {'state': 'Arizona',
#   'feature': 'welfare_per_capita',
#   'min': 222.13263454948597,
#   'max': 655.7827376307165},
#  {'state': 'Arkansas', 'feature': 'crime_rate', 'min': 321.4, 'max': 595.1},
#  {'state': 'Arkansas', 'feature': 'unemployment_rate', 'min': 3.5, 'max': 8.5},
#  {'state': 'Arkansas',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Arkansas',
#   'feature': 'homeownership_rate',
#   'min': 64.7,
#   'max': 71.2},
#  {'state': 'Arkansas',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.25},
#  {'state': 'Arkansas', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Arkansas', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Arkansas',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Arkansas', 'feature': 'poverty_rate', 'min': 12.6, 'max': 28.2},
#  {'state': 'Arkansas',
#   'feature': 'education_per_capita',
#   'min': 604.9307958477509,
#   'max': 2916.600265604249},
#  {'state': 'Arkansas',
#   'feature': 'welfare_per_capita',
#   'min': 265.0497512437811,
#   'max': 657.1184120465434},
#  {'state': 'California', 'feature': 'crime_rate', 'min': 396.4, 'max': 1119.7},
#  {'state': 'California',
#   'feature': 'unemployment_rate',
#   'min': 4.2,
#   'max': 12.5},
#  {'state': 'California',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'California',
#   'feature': 'homeownership_rate',
#   'min': 53.6,
#   'max': 60.2},
#  {'state': 'California',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 12.0},
#  {'state': 'California',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'California', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'California',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'California', 'feature': 'poverty_rate', 'min': 11.8, 'max': 26.6},
#  {'state': 'California',
#   'feature': 'education_per_capita',
#   'min': 761.8990708971048,
#   'max': 3825.4348597799076},
#  {'state': 'California',
#   'feature': 'welfare_per_capita',
#   'min': 517.132503180539,
#   'max': 1477.6809437772345},
#  {'state': 'Colorado', 'feature': 'crime_rate', 'min': 305.4, 'max': 578.8},
#  {'state': 'Colorado', 'feature': 'unemployment_rate', 'min': 2.6, 'max': 9.2},
#  {'state': 'Colorado',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Colorado',
#   'feature': 'homeownership_rate',
#   'min': 58.6,
#   'max': 71.3},
#  {'state': 'Colorado',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 12.0},
#  {'state': 'Colorado', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Colorado', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Colorado',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Colorado', 'feature': 'poverty_rate', 'min': 9.4, 'max': 19.3},
#  {'state': 'Colorado',
#   'feature': 'education_per_capita',
#   'min': 891.7898193760263,
#   'max': 3336.8088467614534},
#  {'state': 'Colorado',
#   'feature': 'welfare_per_capita',
#   'min': 309.81294964028774,
#   'max': 852.6545166402535},
#  {'state': 'Connecticut', 'feature': 'crime_rate', 'min': 183.6, 'max': 553.7},
#  {'state': 'Connecticut',
#   'feature': 'unemployment_rate',
#   'min': 2.1,
#   'max': 9.6},
#  {'state': 'Connecticut',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Connecticut',
#   'feature': 'homeownership_rate',
#   'min': 63.8,
#   'max': 73.0},
#  {'state': 'Connecticut',
#   'feature': 'minimum_wage_effective',
#   'min': 3.37,
#   'max': 11.0},
#  {'state': 'Connecticut',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Connecticut',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'Connecticut',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Connecticut', 'feature': 'poverty_rate', 'min': 8.7, 'max': 13.9},
#  {'state': 'Connecticut',
#   'feature': 'education_per_capita',
#   'min': 695.4373820012586,
#   'max': 4275.771172181716},
#  {'state': 'Connecticut',
#   'feature': 'welfare_per_capita',
#   'min': 420.2013845185652,
#   'max': 1322.54819782062},
#  {'state': 'Delaware', 'feature': 'crime_rate', 'min': 422.5, 'max': 785.9},
#  {'state': 'Delaware', 'feature': 'unemployment_rate', 'min': 3.0, 'max': 8.7},
#  {'state': 'Delaware',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Delaware',
#   'feature': 'homeownership_rate',
#   'min': 67.7,
#   'max': 77.3},
#  {'state': 'Delaware',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.25},
#  {'state': 'Delaware', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Delaware', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Delaware',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Delaware', 'feature': 'poverty_rate', 'min': 10.0, 'max': 16.8},
#  {'state': 'Delaware',
#   'feature': 'education_per_capita',
#   'min': 944.5337620578778,
#   'max': 4294.268167860799},
#  {'state': 'Delaware',
#   'feature': 'welfare_per_capita',
#   'min': 283.147853736089,
#   'max': 992.1111111111111},
#  {'state': 'Florida', 'feature': 'crime_rate', 'min': 378.4, 'max': 1244.3},
#  {'state': 'Florida', 'feature': 'unemployment_rate', 'min': 2.5, 'max': 10.8},
#  {'state': 'Florida',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Florida',
#   'feature': 'homeownership_rate',
#   'min': 64.1,
#   'max': 72.4},
#  {'state': 'Florida',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 8.56},
#  {'state': 'Florida', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Florida', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Florida',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Florida', 'feature': 'poverty_rate', 'min': 12.7, 'max': 22.5},
#  {'state': 'Florida',
#   'feature': 'education_per_capita',
#   'min': 630.130084279956,
#   'max': 2278.8156752062528},
#  {'state': 'Florida',
#   'feature': 'welfare_per_capita',
#   'min': 173.11286185415904,
#   'max': 687.7799002440836},
#  {'state': 'Georgia', 'feature': 'crime_rate', 'min': 338.9, 'max': 756.3},
#  {'state': 'Georgia', 'feature': 'unemployment_rate', 'min': 3.5, 'max': 10.7},
#  {'state': 'Georgia',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Georgia',
#   'feature': 'homeownership_rate',
#   'min': 62.3,
#   'max': 71.8},
#  {'state': 'Georgia',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Georgia', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Georgia', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Georgia',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Georgia', 'feature': 'poverty_rate', 'min': 13.5, 'max': 23.0},
#  {'state': 'Georgia',
#   'feature': 'education_per_capita',
#   'min': 615.438536501966,
#   'max': 2829.262325931502},
#  {'state': 'Georgia',
#   'feature': 'welfare_per_capita',
#   'min': 245.8900655572365,
#   'max': 656.322075782537},
#  {'state': 'Hawaii', 'feature': 'crime_rate', 'min': 219.4, 'max': 295.6},
#  {'state': 'Hawaii', 'feature': 'unemployment_rate', 'min': 2.2, 'max': 6.8},
#  {'state': 'Hawaii',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Hawaii',
#   'feature': 'homeownership_rate',
#   'min': 50.2,
#   'max': 60.6},
#  {'state': 'Hawaii',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 10.1},
#  {'state': 'Hawaii', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Hawaii', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Hawaii',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Hawaii', 'feature': 'poverty_rate', 'min': 9.0, 'max': 24.1},
#  {'state': 'Hawaii',
#   'feature': 'education_per_capita',
#   'min': 707.3529411764706,
#   'max': 2772.972972972973},
#  {'state': 'Hawaii',
#   'feature': 'welfare_per_capita',
#   'min': 404.86641221374043,
#   'max': 1060.190615835777},
#  {'state': 'Idaho', 'feature': 'crime_rate', 'min': 202.2, 'max': 322.0},
#  {'state': 'Idaho', 'feature': 'unemployment_rate', 'min': 2.8, 'max': 8.8},
#  {'state': 'Idaho',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Idaho', 'feature': 'homeownership_rate', 'min': 68.4, 'max': 75.5},
#  {'state': 'Idaho',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Idaho', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Idaho', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Idaho',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Idaho', 'feature': 'poverty_rate', 'min': 9.2, 'max': 22.8},
#  {'state': 'Idaho',
#   'feature': 'education_per_capita',
#   'min': 665.015479876161,
#   'max': 2231.906392694064},
#  {'state': 'Idaho',
#   'feature': 'welfare_per_capita',
#   'min': 235.60371517027866,
#   'max': 707.511139401655},
#  {'state': 'Illinois', 'feature': 'crime_rate', 'min': 370.9, 'max': 1039.2},
#  {'state': 'Illinois',
#   'feature': 'unemployment_rate',
#   'min': 4.0,
#   'max': 10.5},
#  {'state': 'Illinois',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Illinois',
#   'feature': 'homeownership_rate',
#   'min': 60.6,
#   'max': 72.7},
#  {'state': 'Illinois',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.25},
#  {'state': 'Illinois', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Illinois', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Illinois',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Illinois', 'feature': 'poverty_rate', 'min': 11.4, 'max': 20.7},
#  {'state': 'Illinois',
#   'feature': 'education_per_capita',
#   'min': 699.2387119355967,
#   'max': 3105.7996070726917},
#  {'state': 'Illinois',
#   'feature': 'welfare_per_capita',
#   'min': 428.3076653832691,
#   'max': 1080.7958881707032},
#  {'state': 'Indiana', 'feature': 'crime_rate', 'min': 305.2, 'max': 537.0},
#  {'state': 'Indiana', 'feature': 'unemployment_rate', 'min': 2.9, 'max': 10.5},
#  {'state': 'Indiana',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Indiana',
#   'feature': 'homeownership_rate',
#   'min': 66.1,
#   'max': 75.8},
#  {'state': 'Indiana',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Indiana', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Indiana', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Indiana',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Indiana', 'feature': 'poverty_rate', 'min': 8.4, 'max': 18.3},
#  {'state': 'Indiana',
#   'feature': 'education_per_capita',
#   'min': 715.9470246734398,
#   'max': 2801.896088384592},
#  {'state': 'Indiana',
#   'feature': 'welfare_per_capita',
#   'min': 211.34915014164307,
#   'max': 885.3027268525651},
#  {'state': 'Iowa', 'feature': 'crime_rate', 'min': 198.7, 'max': 354.4},
#  {'state': 'Iowa', 'feature': 'unemployment_rate', 'min': 2.6, 'max': 7.4},
#  {'state': 'Iowa',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Iowa', 'feature': 'homeownership_rate', 'min': 66.3, 'max': 76.6},
#  {'state': 'Iowa',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Iowa', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Iowa', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Iowa',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Iowa', 'feature': 'poverty_rate', 'min': 7.7, 'max': 19.4},
#  {'state': 'Iowa',
#   'feature': 'education_per_capita',
#   'min': 870.7487753673897,
#   'max': 3595.1428571428573},
#  {'state': 'Iowa',
#   'feature': 'welfare_per_capita',
#   'min': 337.2288313505948,
#   'max': 752.7040314650934},
#  {'state': 'Kansas', 'feature': 'crime_rate', 'min': 334.2, 'max': 510.8},
#  {'state': 'Kansas', 'feature': 'unemployment_rate', 'min': 3.2, 'max': 7.0},
#  {'state': 'Kansas',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Kansas',
#   'feature': 'homeownership_rate',
#   'min': 63.2,
#   'max': 72.7},
#  {'state': 'Kansas',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Kansas', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Kansas', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Kansas',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Kansas', 'feature': 'poverty_rate', 'min': 10.2, 'max': 16.3},
#  {'state': 'Kansas',
#   'feature': 'education_per_capita',
#   'min': 832.835201328352,
#   'max': 3465.8771026433233},
#  {'state': 'Kansas',
#   'feature': 'welfare_per_capita',
#   'min': 220.15122873345933,
#   'max': 722.21833449965},
#  {'state': 'Kentucky', 'feature': 'crime_rate', 'min': 210.9, 'max': 535.5},
#  {'state': 'Kentucky',
#   'feature': 'unemployment_rate',
#   'min': 4.1,
#   'max': 10.8},
#  {'state': 'Kentucky',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Kentucky',
#   'feature': 'homeownership_rate',
#   'min': 64.9,
#   'max': 75.1},
#  {'state': 'Kentucky',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Kentucky', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Kentucky', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Kentucky',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Kentucky', 'feature': 'poverty_rate', 'min': 13.3, 'max': 24.5},
#  {'state': 'Kentucky',
#   'feature': 'education_per_capita',
#   'min': 623.0727322255517,
#   'max': 2938.77688172043},
#  {'state': 'Kentucky',
#   'feature': 'welfare_per_capita',
#   'min': 304.3410041841004,
#   'max': 781.2557497700093},
#  {'state': 'Louisiana', 'feature': 'crime_rate', 'min': 496.3, 'max': 1061.7},
#  {'state': 'Louisiana',
#   'feature': 'unemployment_rate',
#   'min': 4.1,
#   'max': 12.5},
#  {'state': 'Louisiana',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Louisiana',
#   'feature': 'homeownership_rate',
#   'min': 63.3,
#   'max': 73.5},
#  {'state': 'Louisiana',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Louisiana',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Louisiana', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Louisiana',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Louisiana', 'feature': 'poverty_rate', 'min': 16.3, 'max': 27.3},
#  {'state': 'Louisiana',
#   'feature': 'education_per_capita',
#   'min': 765.693257359924,
#   'max': 2860.863031343924},
#  {'state': 'Louisiana',
#   'feature': 'welfare_per_capita',
#   'min': 240.87608339189504,
#   'max': 1512.3090745732256},
#  {'state': 'Maine', 'feature': 'crime_rate', 'min': 103.7, 'max': 167.5},
#  {'state': 'Maine', 'feature': 'unemployment_rate', 'min': 2.7, 'max': 8.4},
#  {'state': 'Maine',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Maine', 'feature': 'homeownership_rate', 'min': 69.9, 'max': 77.4},
#  {'state': 'Maine',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 12.0},
#  {'state': 'Maine', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Maine', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Maine',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Maine', 'feature': 'poverty_rate', 'min': 9.4, 'max': 18.0},
#  {'state': 'Maine',
#   'feature': 'education_per_capita',
#   'min': 671.6738197424893,
#   'max': 2790.8208955223877},
#  {'state': 'Maine',
#   'feature': 'welfare_per_capita',
#   'min': 421.6309012875536,
#   'max': 1370.8489857250188},
#  {'state': 'Maryland', 'feature': 'crime_rate', 'min': 448.0, 'max': 1000.1},
#  {'state': 'Maryland', 'feature': 'unemployment_rate', 'min': 3.5, 'max': 7.8},
#  {'state': 'Maryland',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Maryland',
#   'feature': 'homeownership_rate',
#   'min': 62.7,
#   'max': 72.6},
#  {'state': 'Maryland',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 11.0},
#  {'state': 'Maryland', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Maryland', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Maryland',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Maryland', 'feature': 'poverty_rate', 'min': 9.1, 'max': 15.6},
#  {'state': 'Maryland',
#   'feature': 'education_per_capita',
#   'min': 812.9003157419937,
#   'max': 3557.5968222442903},
#  {'state': 'Maryland',
#   'feature': 'welfare_per_capita',
#   'min': 348.7595850248083,
#   'max': 997.7198134392814},
#  {'state': 'Massachusetts',
#   'feature': 'crime_rate',
#   'min': 327.6,
#   'max': 804.9},
#  {'state': 'Massachusetts',
#   'feature': 'unemployment_rate',
#   'min': 2.8,
#   'max': 8.8},
#  {'state': 'Massachusetts',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Massachusetts',
#   'feature': 'homeownership_rate',
#   'min': 58.6,
#   'max': 65.8},
#  {'state': 'Massachusetts',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 12.75},
#  {'state': 'Massachusetts',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Massachusetts',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'Massachusetts',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Massachusetts',
#   'feature': 'poverty_rate',
#   'min': 9.5,
#   'max': 17.4},
#  {'state': 'Massachusetts',
#   'feature': 'education_per_capita',
#   'min': 653.1896699161963,
#   'max': 3584.191443074692},
#  {'state': 'Massachusetts',
#   'feature': 'welfare_per_capita',
#   'min': 537.1643577903199,
#   'max': 1572.0225403594272},
#  {'state': 'Michigan', 'feature': 'crime_rate', 'min': 420.6, 'max': 803.9},
#  {'state': 'Michigan',
#   'feature': 'unemployment_rate',
#   'min': 3.6,
#   'max': 13.1},
#  {'state': 'Michigan',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Michigan',
#   'feature': 'homeownership_rate',
#   'min': 70.6,
#   'max': 77.4},
#  {'state': 'Michigan',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.65},
#  {'state': 'Michigan', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Michigan', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Michigan',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Michigan', 'feature': 'poverty_rate', 'min': 11.6, 'max': 20.0},
#  {'state': 'Michigan',
#   'feature': 'education_per_capita',
#   'min': 847.3423180592991,
#   'max': 3299.5393089634454},
#  {'state': 'Michigan',
#   'feature': 'welfare_per_capita',
#   'min': 459.1678564144402,
#   'max': 1080.805831139907},
#  {'state': 'Minnesota', 'feature': 'crime_rate', 'min': 211.5, 'max': 359.0},
#  {'state': 'Minnesota',
#   'feature': 'unemployment_rate',
#   'min': 2.7,
#   'max': 7.9},
#  {'state': 'Minnesota',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Minnesota',
#   'feature': 'homeownership_rate',
#   'min': 65.8,
#   'max': 77.3},
#  {'state': 'Minnesota',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 8.15},
#  {'state': 'Minnesota',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Minnesota', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Minnesota',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Minnesota', 'feature': 'poverty_rate', 'min': 7.6, 'max': 17.9},
#  {'state': 'Minnesota',
#   'feature': 'education_per_capita',
#   'min': 897.9966611018365,
#   'max': 3620.9841326439646},
#  {'state': 'Minnesota',
#   'feature': 'welfare_per_capita',
#   'min': 510.4221321249702,
#   'max': 1165.9762756543023},
#  {'state': 'Mississippi', 'feature': 'crime_rate', 'min': 256.2, 'max': 502.8},
#  {'state': 'Mississippi',
#   'feature': 'unemployment_rate',
#   'min': 5.0,
#   'max': 11.4},
#  {'state': 'Mississippi',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Mississippi',
#   'feature': 'homeownership_rate',
#   'min': 69.2,
#   'max': 78.8},
#  {'state': 'Mississippi',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Mississippi',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Mississippi',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'Mississippi',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Mississippi', 'feature': 'poverty_rate', 'min': 15.7, 'max': 30.0},
#  {'state': 'Mississippi',
#   'feature': 'education_per_capita',
#   'min': 610.8182533438238,
#   'max': 2794.4257891202146},
#  {'state': 'Mississippi',
#   'feature': 'welfare_per_capita',
#   'min': 213.5653409090909,
#   'max': 562.7061595422416},
#  {'state': 'Missouri', 'feature': 'crime_rate', 'min': 433.7, 'max': 763.0},
#  {'state': 'Missouri', 'feature': 'unemployment_rate', 'min': 3.2, 'max': 9.5},
#  {'state': 'Missouri',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Missouri',
#   'feature': 'homeownership_rate',
#   'min': 63.7,
#   'max': 74.8},
#  {'state': 'Missouri',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.45},
#  {'state': 'Missouri', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Missouri', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Missouri',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Missouri', 'feature': 'poverty_rate', 'min': 10.1, 'max': 19.6},
#  {'state': 'Missouri',
#   'feature': 'education_per_capita',
#   'min': 612.2097678142513,
#   'max': 2609.2508143322475},
#  {'state': 'Missouri',
#   'feature': 'welfare_per_capita',
#   'min': 239.13130504403523,
#   'max': 670.4969979986657},
#  {'state': 'Montana', 'feature': 'crime_rate', 'min': 116.0, 'max': 404.9},
#  {'state': 'Montana', 'feature': 'unemployment_rate', 'min': 3.3, 'max': 7.9},
#  {'state': 'Montana',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Montana',
#   'feature': 'homeownership_rate',
#   'min': 64.4,
#   'max': 72.4},
#  {'state': 'Montana',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 8.65},
#  {'state': 'Montana', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Montana', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Montana',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Montana', 'feature': 'poverty_rate', 'min': 11.3, 'max': 22.4},
#  {'state': 'Montana',
#   'feature': 'education_per_capita',
#   'min': 960.9848484848485,
#   'max': 2935.0282485875705},
#  {'state': 'Montana',
#   'feature': 'welfare_per_capita',
#   'min': 295.2380952380953,
#   'max': 858.8294651866802},
#  {'state': 'Nebraska', 'feature': 'crime_rate', 'min': 225.8, 'max': 451.4},
#  {'state': 'Nebraska', 'feature': 'unemployment_rate', 'min': 2.4, 'max': 5.1},
#  {'state': 'Nebraska',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Nebraska',
#   'feature': 'homeownership_rate',
#   'min': 66.1,
#   'max': 71.2},
#  {'state': 'Nebraska',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.0},
#  {'state': 'Nebraska', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Nebraska', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Nebraska',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Nebraska', 'feature': 'poverty_rate', 'min': 8.8, 'max': 20.3},
#  {'state': 'Nebraska',
#   'feature': 'education_per_capita',
#   'min': 840.1780038143675,
#   'max': 3859.154929577465},
#  {'state': 'Nebraska',
#   'feature': 'welfare_per_capita',
#   'min': 253.90972663699935,
#   'max': 769.0163934426229},
#  {'state': 'Nevada', 'feature': 'crime_rate', 'min': 493.8, 'max': 1001.9},
#  {'state': 'Nevada', 'feature': 'unemployment_rate', 'min': 3.9, 'max': 13.8},
#  {'state': 'Nevada',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Nevada',
#   'feature': 'homeownership_rate',
#   'min': 54.1,
#   'max': 65.7},
#  {'state': 'Nevada',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Nevada', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Nevada', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Nevada',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Nevada', 'feature': 'poverty_rate', 'min': 12.6, 'max': 20.5},
#  {'state': 'Nevada',
#   'feature': 'education_per_capita',
#   'min': 598.619957537155,
#   'max': 2638.4988676803623},
#  {'state': 'Nevada',
#   'feature': 'welfare_per_capita',
#   'min': 273.4072022160665,
#   'max': 1132.9755736491488},
#  {'state': 'New Hampshire',
#   'feature': 'crime_rate',
#   'min': 96.5,
#   'max': 223.2},
#  {'state': 'New Hampshire',
#   'feature': 'unemployment_rate',
#   'min': 2.2,
#   'max': 7.3},
#  {'state': 'New Hampshire',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'New Hampshire',
#   'feature': 'homeownership_rate',
#   'min': 64.8,
#   'max': 76.0},
#  {'state': 'New Hampshire',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'New Hampshire',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'New Hampshire',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'New Hampshire',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'New Hampshire',
#   'feature': 'poverty_rate',
#   'min': 7.3,
#   'max': 13.9},
#  {'state': 'New Hampshire',
#   'feature': 'education_per_capita',
#   'min': 597.0766129032257,
#   'max': 3167.158671586716},
#  {'state': 'New Hampshire',
#   'feature': 'welfare_per_capita',
#   'min': 265.7258064516129,
#   'max': 1105.433962264151},
#  {'state': 'New Jersey', 'feature': 'crime_rate', 'min': 206.9, 'max': 647.6},
#  {'state': 'New Jersey',
#   'feature': 'unemployment_rate',
#   'min': 3.4,
#   'max': 9.7},
#  {'state': 'New Jersey',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'New Jersey',
#   'feature': 'homeownership_rate',
#   'min': 62.2,
#   'max': 70.1},
#  {'state': 'New Jersey',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 11.0},
#  {'state': 'New Jersey',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'New Jersey', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'New Jersey',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'New Jersey', 'feature': 'poverty_rate', 'min': 9.1, 'max': 16.7},
#  {'state': 'New Jersey',
#   'feature': 'education_per_capita',
#   'min': 789.998668264749,
#   'max': 4281.848852901485},
#  {'state': 'New Jersey',
#   'feature': 'welfare_per_capita',
#   'min': 421.0813690238381,
#   'max': 1439.69769291965},
#  {'state': 'New Mexico', 'feature': 'crime_rate', 'min': 559.6, 'max': 961.4},
#  {'state': 'New Mexico',
#   'feature': 'unemployment_rate',
#   'min': 3.6,
#   'max': 9.2},
#  {'state': 'New Mexico',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'New Mexico',
#   'feature': 'homeownership_rate',
#   'min': 65.4,
#   'max': 73.7},
#  {'state': 'New Mexico',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.0},
#  {'state': 'New Mexico',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'New Mexico', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'New Mexico',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'New Mexico', 'feature': 'poverty_rate', 'min': 15.1, 'max': 26.9},
#  {'state': 'New Mexico',
#   'feature': 'education_per_capita',
#   'min': 975.650289017341,
#   'max': 3330.796019900498},
#  {'state': 'New Mexico',
#   'feature': 'welfare_per_capita',
#   'min': 241.97976878612718,
#   'max': 656.3680387409202},
#  {'state': 'New York', 'feature': 'crime_rate', 'min': 350.8, 'max': 1180.9},
#  {'state': 'New York', 'feature': 'unemployment_rate', 'min': 3.8, 'max': 8.7},
#  {'state': 'New York',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'New York',
#   'feature': 'homeownership_rate',
#   'min': 50.3,
#   'max': 55.9},
#  {'state': 'New York',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 11.8},
#  {'state': 'New York', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'New York', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'New York',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'New York', 'feature': 'poverty_rate', 'min': 13.1, 'max': 22.9},
#  {'state': 'New York',
#   'feature': 'education_per_capita',
#   'min': 900.2594472645234,
#   'max': 4567.253376995497},
#  {'state': 'New York',
#   'feature': 'welfare_per_capita',
#   'min': 699.8195149464184,
#   'max': 1439.8814432989693},
#  {'state': 'North Carolina',
#   'feature': 'crime_rate',
#   'min': 329.1,
#   'max': 681.0},
#  {'state': 'North Carolina',
#   'feature': 'unemployment_rate',
#   'min': 3.3,
#   'max': 11.0},
#  {'state': 'North Carolina',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'North Carolina',
#   'feature': 'homeownership_rate',
#   'min': 65.1,
#   'max': 71.7},
#  {'state': 'North Carolina',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'North Carolina',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'North Carolina',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'North Carolina',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'North Carolina',
#   'feature': 'poverty_rate',
#   'min': 13.6,
#   'max': 21.3},
#  {'state': 'North Carolina',
#   'feature': 'education_per_capita',
#   'min': 687.7795786061589,
#   'max': 2875.145224264356},
#  {'state': 'North Carolina',
#   'feature': 'welfare_per_capita',
#   'min': 225.81847649918961,
#   'max': 869.5039164490862},
#  {'state': 'North Dakota', 'feature': 'crime_rate', 'min': 47.0, 'max': 284.6},
#  {'state': 'North Dakota',
#   'feature': 'unemployment_rate',
#   'min': 2.3,
#   'max': 5.6},
#  {'state': 'North Dakota',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'North Dakota',
#   'feature': 'homeownership_rate',
#   'min': 61.4,
#   'max': 71.0},
#  {'state': 'North Dakota',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'North Dakota',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'North Dakota',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'North Dakota',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'North Dakota', 'feature': 'poverty_rate', 'min': 8.8, 'max': 18.4},
#  {'state': 'North Dakota',
#   'feature': 'education_per_capita',
#   'min': 990.8809891808346,
#   'max': 4284.78835978836},
#  {'state': 'North Dakota',
#   'feature': 'welfare_per_capita',
#   'min': 379.1862284820031,
#   'max': 849.2063492063492},
#  {'state': 'Ohio', 'feature': 'crime_rate', 'min': 285.7, 'max': 561.8},
#  {'state': 'Ohio', 'feature': 'unemployment_rate', 'min': 4.1, 'max': 10.3},
#  {'state': 'Ohio',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Ohio', 'feature': 'homeownership_rate', 'min': 66.0, 'max': 73.3},
#  {'state': 'Ohio',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 8.7},
#  {'state': 'Ohio', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Ohio', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Ohio',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Ohio', 'feature': 'poverty_rate', 'min': 11.0, 'max': 17.1},
#  {'state': 'Ohio',
#   'feature': 'education_per_capita',
#   'min': 718.6835536655265,
#   'max': 3174.822361099221},
#  {'state': 'Ohio',
#   'feature': 'welfare_per_capita',
#   'min': 403.42309046110523,
#   'max': 1148.0977554380795},
#  {'state': 'Oklahoma', 'feature': 'crime_rate', 'min': 407.5, 'max': 664.1},
#  {'state': 'Oklahoma', 'feature': 'unemployment_rate', 'min': 3.0, 'max': 8.3},
#  {'state': 'Oklahoma',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Oklahoma',
#   'feature': 'homeownership_rate',
#   'min': 66.8,
#   'max': 72.9},
#  {'state': 'Oklahoma',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Oklahoma', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Oklahoma', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Oklahoma',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Oklahoma', 'feature': 'poverty_rate', 'min': 12.0, 'max': 21.0},
#  {'state': 'Oklahoma',
#   'feature': 'education_per_capita',
#   'min': 829.9381711682396,
#   'max': 2722.3268839103866},
#  {'state': 'Oklahoma',
#   'feature': 'welfare_per_capita',
#   'min': 233.9828757012105,
#   'max': 656.1968085106383},
#  {'state': 'Oregon', 'feature': 'crime_rate', 'min': 242.8, 'max': 551.1},
#  {'state': 'Oregon', 'feature': 'unemployment_rate', 'min': 3.7, 'max': 10.8},
#  {'state': 'Oregon',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Oregon',
#   'feature': 'homeownership_rate',
#   'min': 61.0,
#   'max': 69.0},
#  {'state': 'Oregon',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 11.25},
#  {'state': 'Oregon', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Oregon', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Oregon',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Oregon', 'feature': 'poverty_rate', 'min': 11.5, 'max': 19.8},
#  {'state': 'Oregon',
#   'feature': 'education_per_capita',
#   'min': 897.1639042357275,
#   'max': 3606.4516129032254},
#  {'state': 'Oregon',
#   'feature': 'welfare_per_capita',
#   'min': 378.7450126949583,
#   'max': 1446.5607210626185},
#  {'state': 'Pennsylvania',
#   'feature': 'crime_rate',
#   'min': 305.4,
#   'max': 480.3},
#  {'state': 'Pennsylvania',
#   'feature': 'unemployment_rate',
#   'min': 4.2,
#   'max': 8.9},
#  {'state': 'Pennsylvania',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Pennsylvania',
#   'feature': 'homeownership_rate',
#   'min': 68.5,
#   'max': 75.2},
#  {'state': 'Pennsylvania',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Pennsylvania',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Pennsylvania',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'Pennsylvania',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Pennsylvania',
#   'feature': 'poverty_rate',
#   'min': 10.8,
#   'max': 18.0},
#  {'state': 'Pennsylvania',
#   'feature': 'education_per_capita',
#   'min': 638.8425574930502,
#   'max': 3576.5606688022503},
#  {'state': 'Pennsylvania',
#   'feature': 'welfare_per_capita',
#   'min': 452.4724117597506,
#   'max': 1300.0078672016364},
#  {'state': 'Rhode Island',
#   'feature': 'crime_rate',
#   'min': 219.8,
#   'max': 462.0},
#  {'state': 'Rhode Island',
#   'feature': 'unemployment_rate',
#   'min': 2.9,
#   'max': 11.6},
#  {'state': 'Rhode Island',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Rhode Island',
#   'feature': 'homeownership_rate',
#   'min': 56.3,
#   'max': 64.9},
#  {'state': 'Rhode Island',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 10.5},
#  {'state': 'Rhode Island',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Rhode Island',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'Rhode Island',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Rhode Island',
#   'feature': 'poverty_rate',
#   'min': 11.6,
#   'max': 17.7},
#  {'state': 'Rhode Island',
#   'feature': 'education_per_capita',
#   'min': 753.044375644995,
#   'max': 3533.2703213610584},
#  {'state': 'Rhode Island',
#   'feature': 'welfare_per_capita',
#   'min': 563.4674922600619,
#   'max': 1276.0910815939278},
#  {'state': 'South Carolina',
#   'feature': 'crime_rate',
#   'min': 497.8,
#   'max': 1030.5},
#  {'state': 'South Carolina',
#   'feature': 'unemployment_rate',
#   'min': 2.8,
#   'max': 11.4},
#  {'state': 'South Carolina',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'South Carolina',
#   'feature': 'homeownership_rate',
#   'min': 67.1,
#   'max': 77.5},
#  {'state': 'South Carolina',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'South Carolina',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'South Carolina',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'South Carolina',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'South Carolina',
#   'feature': 'poverty_rate',
#   'min': 12.9,
#   'max': 23.8},
#  {'state': 'South Carolina',
#   'feature': 'education_per_capita',
#   'min': 654.183266932271,
#   'max': 3083.071484681854},
#  {'state': 'South Carolina',
#   'feature': 'welfare_per_capita',
#   'min': 193.1045050566963,
#   'max': 669.3054357204487},
#  {'state': 'South Dakota',
#   'feature': 'crime_rate',
#   'min': 113.7,
#   'max': 429.8},
#  {'state': 'South Dakota',
#   'feature': 'unemployment_rate',
#   'min': 2.5,
#   'max': 4.9},
#  {'state': 'South Dakota',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'South Dakota',
#   'feature': 'homeownership_rate',
#   'min': 65.6,
#   'max': 71.5},
#  {'state': 'South Dakota',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 9.3},
#  {'state': 'South Dakota',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'South Dakota',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'South Dakota',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'South Dakota', 'feature': 'poverty_rate', 'min': 9.8, 'max': 22.1},
#  {'state': 'South Dakota',
#   'feature': 'education_per_capita',
#   'min': 654.183266932271,
#   'max': 3083.071484681854},
#  {'state': 'South Dakota',
#   'feature': 'welfare_per_capita',
#   'min': 193.1045050566963,
#   'max': 669.3054357204487},
#  {'state': 'Tennessee', 'feature': 'crime_rate', 'min': 445.4, 'max': 789.7},
#  {'state': 'Tennessee',
#   'feature': 'unemployment_rate',
#   'min': 3.4,
#   'max': 10.1},
#  {'state': 'Tennessee',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Tennessee',
#   'feature': 'homeownership_rate',
#   'min': 64.1,
#   'max': 72.4},
#  {'state': 'Tennessee',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Tennessee',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Tennessee', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Tennessee',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Tennessee', 'feature': 'poverty_rate', 'min': 13.7, 'max': 23.9},
#  {'state': 'Tennessee',
#   'feature': 'education_per_capita',
#   'min': 547.2039123963427,
#   'max': 2221.584538211862},
#  {'state': 'Tennessee',
#   'feature': 'welfare_per_capita',
#   'min': 255.6240697427174,
#   'max': 692.546875},
#  {'state': 'Texas', 'feature': 'crime_rate', 'min': 406.7, 'max': 840.1},
#  {'state': 'Texas', 'feature': 'unemployment_rate', 'min': 3.5, 'max': 8.8},
#  {'state': 'Texas',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Texas', 'feature': 'homeownership_rate', 'min': 58.3, 'max': 66.0},
#  {'state': 'Texas',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Texas', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Texas', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Texas',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Texas', 'feature': 'poverty_rate', 'min': 13.6, 'max': 22.7},
#  {'state': 'Texas',
#   'feature': 'education_per_capita',
#   'min': 841.8947230587928,
#   'max': 3483.1614171870146},
#  {'state': 'Texas',
#   'feature': 'welfare_per_capita',
#   'min': 201.83972764174416,
#   'max': 548.4747642817526},
#  {'state': 'Utah', 'feature': 'crime_rate', 'min': 197.1, 'max': 334.0},
#  {'state': 'Utah', 'feature': 'unemployment_rate', 'min': 2.5, 'max': 7.9},
#  {'state': 'Utah',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Utah', 'feature': 'homeownership_rate', 'min': 68.0, 'max': 76.2},
#  {'state': 'Utah',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Utah', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Utah', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Utah',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Utah', 'feature': 'poverty_rate', 'min': 8.8, 'max': 18.2},
#  {'state': 'Utah',
#   'feature': 'education_per_capita',
#   'min': 929.0839205637412,
#   'max': 3366.6244057052304},
#  {'state': 'Utah',
#   'feature': 'welfare_per_capita',
#   'min': 260.75353218210364,
#   'max': 718.3063063063063},
#  {'state': 'Vermont', 'feature': 'crime_rate', 'min': 96.9, 'max': 202.2},
#  {'state': 'Vermont', 'feature': 'unemployment_rate', 'min': 2.3, 'max': 6.3},
#  {'state': 'Vermont',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Vermont',
#   'feature': 'homeownership_rate',
#   'min': 66.9,
#   'max': 74.6},
#  {'state': 'Vermont',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 10.96},
#  {'state': 'Vermont', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Vermont', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Vermont',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Vermont', 'feature': 'poverty_rate', 'min': 8.8, 'max': 17.7},
#  {'state': 'Vermont',
#   'feature': 'education_per_capita',
#   'min': 848.3992467043314,
#   'max': 4933.12},
#  {'state': 'Vermont',
#   'feature': 'welfare_per_capita',
#   'min': 382.2975517890772,
#   'max': 1518.0511182108626},
#  {'state': 'Virginia', 'feature': 'crime_rate', 'min': 191.5, 'max': 374.9},
#  {'state': 'Virginia', 'feature': 'unemployment_rate', 'min': 2.3, 'max': 7.3},
#  {'state': 'Virginia',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Virginia',
#   'feature': 'homeownership_rate',
#   'min': 66.0,
#   'max': 75.1},
#  {'state': 'Virginia',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Virginia', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Virginia', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Virginia',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Virginia', 'feature': 'poverty_rate', 'min': 9.9, 'max': 15.9},
#  {'state': 'Virginia',
#   'feature': 'education_per_capita',
#   'min': 740.8080451658433,
#   'max': 3290.3003389038213},
#  {'state': 'Virginia',
#   'feature': 'welfare_per_capita',
#   'min': 215.80804516584334,
#   'max': 706.3434695912264},
#  {'state': 'Washington', 'feature': 'crime_rate', 'min': 285.8, 'max': 534.5},
#  {'state': 'Washington',
#   'feature': 'unemployment_rate',
#   'min': 4.1,
#   'max': 9.3},
#  {'state': 'Washington',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Washington',
#   'feature': 'homeownership_rate',
#   'min': 61.6,
#   'max': 67.6},
#  {'state': 'Washington',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 13.5},
#  {'state': 'Washington',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Washington', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Washington',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Washington', 'feature': 'poverty_rate', 'min': 9.8, 'max': 17.2},
#  {'state': 'Washington',
#   'feature': 'education_per_capita',
#   'min': 842.3617407071623,
#   'max': 3623.1167795934634},
#  {'state': 'Washington',
#   'feature': 'welfare_per_capita',
#   'min': 456.18766999093384,
#   'max': 1236.0077117010233},
#  {'state': 'West Virginia',
#   'feature': 'crime_rate',
#   'min': 131.4,
#   'max': 362.7},
#  {'state': 'West Virginia',
#   'feature': 'unemployment_rate',
#   'min': 4.7,
#   'max': 14.1},
#  {'state': 'West Virginia',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'West Virginia',
#   'feature': 'homeownership_rate',
#   'min': 72.0,
#   'max': 81.3},
#  {'state': 'West Virginia',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 8.75},
#  {'state': 'West Virginia',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'West Virginia',
#   'feature': 'inflation_rate',
#   'min': -0.4,
#   'max': 5.4},
#  {'state': 'West Virginia',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'West Virginia',
#   'feature': 'poverty_rate',
#   'min': 11.6,
#   'max': 27.9},
#  {'state': 'West Virginia',
#   'feature': 'education_per_capita',
#   'min': 729.1092258748674,
#   'max': 3037.102854065697},
#  {'state': 'West Virginia',
#   'feature': 'welfare_per_capita',
#   'min': 281.62700608743774,
#   'max': 744.4075304540421},
#  {'state': 'Wisconsin', 'feature': 'crime_rate', 'min': 196.5, 'max': 321.8},
#  {'state': 'Wisconsin',
#   'feature': 'unemployment_rate',
#   'min': 3.0,
#   'max': 9.0},
#  {'state': 'Wisconsin',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Wisconsin',
#   'feature': 'homeownership_rate',
#   'min': 63.8,
#   'max': 73.3},
#  {'state': 'Wisconsin',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Wisconsin',
#   'feature': 'CPI_Average',
#   'min': 103.9,
#   'max': 255.657},
#  {'state': 'Wisconsin', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Wisconsin',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Wisconsin', 'feature': 'poverty_rate', 'min': 8.5, 'max': 16.2},
#  {'state': 'Wisconsin',
#   'feature': 'education_per_capita',
#   'min': 913.622096672944,
#   'max': 3452.2403433476393},
#  {'state': 'Wisconsin',
#   'feature': 'welfare_per_capita',
#   'min': 457.60619376438586,
#   'max': 1118.6259005447198},
#  {'state': 'Wyoming', 'feature': 'crime_rate', 'min': 195.4, 'max': 319.5},
#  {'state': 'Wyoming', 'feature': 'unemployment_rate', 'min': 2.6, 'max': 8.6},
#  {'state': 'Wyoming',
#   'feature': 'divorce_rate_per_1000_people',
#   'min': 2.7,
#   'max': 4.9778},
#  {'state': 'Wyoming',
#   'feature': 'homeownership_rate',
#   'min': 65.8,
#   'max': 73.8},
#  {'state': 'Wyoming',
#   'feature': 'minimum_wage_effective',
#   'min': 3.35,
#   'max': 7.25},
#  {'state': 'Wyoming', 'feature': 'CPI_Average', 'min': 103.9, 'max': 255.657},
#  {'state': 'Wyoming', 'feature': 'inflation_rate', 'min': -0.4, 'max': 5.4},
#  {'state': 'Wyoming',
#   'feature': 'avg_wage_index',
#   'min': 16135.07,
#   'max': 54099.99},
#  {'state': 'Wyoming', 'feature': 'poverty_rate', 'min': 8.6, 'max': 17.1},
#  {'state': 'Wyoming',
#   'feature': 'education_per_capita',
#   'min': 1666.3736263736264,
#   'max': 5437.606837606838},
#  {'state': 'Wyoming',
#   'feature': 'welfare_per_capita',
#   'min': 250.0,
#   'max': 856.637168141593}]

# %%
# Create dataframe
min_max_df = pd.DataFrame(data)
min_max_df.head()
# Out:
#       state                       feature         min         max
# 0  National                    crime_rate  372.000000  758.100000
# 1  National             unemployment_rate    3.718367    9.860857
# 2  National  divorce_rate_per_1000_people    2.700000    5.300000
# 3  National            homeownership_rate    3.720000    9.860000
# 4  National        minimum_wage_effective    2.226667    9.068824

# %%
# Check dataframe for a state
ca_feat_values = min_max_df.loc[min_max_df['state'] == 'California']
ca_feat_values
# Out:
#          state                       feature           min           max
# 55  California                    crime_rate    396.400000   1119.700000
# 56  California             unemployment_rate      4.200000     12.500000
# 57  California  divorce_rate_per_1000_people      2.700000      4.977800
# 58  California            homeownership_rate     53.600000     60.200000
# 59  California        minimum_wage_effective      3.350000     12.000000
# 60  California                   CPI_Average    103.900000    255.657000
# 61  California                inflation_rate     -0.400000      5.400000
# 62  California                avg_wage_index  16135.070000  54099.990000
# 63  California                  poverty_rate     11.800000     26.600000
# 64  California          education_per_capita    761.899071   3825.434860
# 65  California            welfare_per_capita    517.132503   1477.680944

# %%
# Getting a max value for a feature
ca_max_crime = ca_feat_values.loc[ca_feat_values['feature'] == 'crime_rate']['max'].item()
ca_max_crime
# Out:
# 1119.7

# %%
# Getting a min value for a feature
ca_min_crime = ca_feat_values.loc[ca_feat_values['feature'] == 'crime_rate']['min'].item()
ca_min_crime
# Out:
# 396.4

# %%
# Export csv to be used
min_max_df.to_csv('min_max_values.csv', index = False)
